# %%
import torch
print(torch.__version__)

# %%
# installing pointnet++
# !pip install ninja
# !git clone https://github.com/erikwijmans/Pointnet2_PyTorch
# %cd /content/Pointnet2_PyTorch
# !python setup.py install

# moving to root directory
# %cd ..

# %%
# install minimal requirements (pytorch is already installed in colab)
# !pip install timm==0.5.4 wandb tqdm h5py==3.6.0 protobuf==3.20.1 lmdb==1.2.1 msgpack-numpy==0.4.7.1 scikit-learn

# %%
# made a new repo for you starting from 3DOS with modifications to help you running the code with colab.
# !rm -r SemNov_AML_DAAI_23-24/
# !git clone https://github.com/GNNatan/SemNov_AML_DAAI_23-24

# %%
# !ls

# %%
# Move to the project directory after Git clone
# %cd /content/SemNov_AML_DAAI_23-24

# %%
# !ls /content/SemNov_AML_DAAI_23-24

# %%
# check we're in project directory (should be SemNov_AML_DAAI_23)
# !pwd

# %%
# !pip install "https://github.com/unlimblue/KNN_CUDA/releases/download/0.2/KNN_CUDA-0.2-py3-none-any.whl"

# %%
# !sh download_data.sh

# %% [markdown]
# ## train

# %% [markdown]
# ### dgcnn

# %%
# train dgcnn_ce_SR1
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-am

# %%
# train dgcnn_ce_SR2
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR2 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-am

# %%
# train dgcnn_ce-ls_SR1
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE-ls_SR1 --src SR1 --loss CE_ls --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-am

# %%
# train dgcnn_ce-ls_SR2
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE-ls_SR2 --src SR2 --loss CE_ls --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-am

# %% [markdown]
# ### pn2

# %%
# train pn2_CE_SR1
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE_SR1 --batch_size 16 --src SR1 --loss CE --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-aml

# %%
# train pn2_CE_SR2
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE_SR2 --batch_size 16 --src SR2 --loss CE --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-aml

# %%
# train pn2_CE-ls_SR1
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE-ls_SR1 --batch_size 16 --src SR1 --loss CE_ls --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-aml

# %%
# train pn2_CE_SR2
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE-ls_SR2 --batch_size 16 --src SR2 --loss CE_ls --wandb_proj AML_DAAI_proj23_24 --wandb_group sng-aml

# %% [markdown]
# ### zip

# %%
# zip
# !zip -r PointNet2_CE_SR2.zip outputs/PointNet2_CE_SR2/

# %%
from google.colab import files
files.download("PointNet2_CE_SR2.zip")

# %% [markdown]
# # eval

# %% [markdown]
# ## dgcnn

# %%
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR1 --src SR1 --loss CE -mode eval --ckpt_path outputs/DGCNN_CE_SR1/models/model_last.pth

# %%
# !python classifiers/trainer_cla_md.py --config cfgs/dgcnn-cla.yaml --exp_name DGCNN_CE_SR2 --src SR2 --loss CE -mode eval --ckpt_path outputs/DGCNN_CE_SR2/models/model_last.pth

# %% [markdown]
# ## pn2

# %%
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE_SR1_eval --src SR1 --loss CE -mode eval --ckpt_path outputs/PointNet2_CE_SR1/models/model_last.pth

# %%
# !python classifiers/trainer_cla_md.py --config cfgs/pn2-msg.yaml --exp_name PointNet2_CE_SR2_eval --src SR2 --loss CE -mode eval --ckpt_path outputs/PointNet2_CE_SR2/models/model_last.pth
