# %%
# %cd /content
# !rm -r dgcnn-saliency
# !git clone https://github.com/s316379/dgcnn-saliency.git
# Out:
# /content
# rm: cannot remove 'dgcnn-saliency': No such file or directory
# Cloning into 'dgcnn-saliency'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (163/163), done.
# remote: Compressing objects: 100% (113/113), done.
# remote: Total 163 (delta 66), reused 139 (delta 42), pack-reused 0
# Receiving objects: 100% (163/163), 23.06 MiB | 12.55 MiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
# %cd dgcnn-saliency
# %cd ..
# Out:
# /content/dgcnn-saliency

# %%
# !rm -r dgcnn-saliency

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for cprint: filename=cprint-1.2.2-py3-none-any.whl size=2519 sha256=679a8fb8cd71bc8f3bc98eaf3980f180b731143cfe008e0e6e6fd538bb20a169
#   Stored in directory: /root/.cache/pip/wheels/e8/c7/77/b74864ee8de3abb693e3be291549a29c6ff242ce66801b1622
# Successfully built cprint
# ...

# %%
# !rm -r /content/dgcnn-saliency/dump/*
# !python main.py --model_path dgcnn-master/pytorch/pretrained/model.1024.t7 --test_batch_size 32
# Out:
# rm: cannot remove '/content/dgcnn-saliency/dump/*': No such file or directory
# --2024-06-05 13:29:31--  https://shapenet.cs.stanford.edu/media/modelnet40_ply_hdf5_2048.zip
# Resolving shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)... 171.67.77.19
# Connecting to shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)|171.67.77.19|:443... connected.
# WARNING: cannot verify shapenet.cs.stanford.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Issued certificate has expired.
# HTTP request sent, awaiting response... 200 OK
# Length: 435212151 (415M) [application/zip]
# Saving to: ‘/content/dgcnn-saliency/dgcnn-master/pytorch/data/modelnet40_ply_hdf5_2048.zip’
#
# modelnet40_ply_hdf5 100%[===================>] 415.05M  10.1MB/s    in 35s
#
# 2024-06-05 13:30:07 (11.8 MB/s) - ‘/content/dgcnn-saliency/dgcnn-master/pytorch/data/modelnet40_ply_hdf5_2048.zip’ saved [435212151/435212151]
#
# ...

# %%
# !rm -r /content/dgcnn-saliency/dump/*
# !python main.py --model_path dgcnn-master/pytorch/pretrained/model.1024.t7 --test_batch_size 32 --drop_neg
# Out:
# rm: cannot remove '/content/dgcnn-saliency/dump/*': No such file or directory
# Test natural:: test acc: 0.928687, test avg acc: 0.898744
# [ 4  0  2 ... 25 37 25] [ 4  0  2 ...  2 37 25]
# Test adversial:: test acc: 0.949757, test avg acc: 0.920738

# %%
# !git pull https://github.com/s316379/dgcnn-saliency.git
# Out:
# From https://github.com/s316379/dgcnn-saliency
#  * branch            HEAD       -> FETCH_HEAD
# Already up to date.

# %%
# !zip -r dump_neg.zip dump
# Out:
#   adding: dump/ (stored 0%)
#   adding: dump/pred_wrong_adv_correct/ (stored 0%)
#   adding: dump/pred_wrong_adv_correct/label_table_pred_desk_11_6adv_z.jpg (deflated 19%)
#   adding: dump/pred_wrong_adv_correct/label_night_stand_pred_table_0_4adv_y.jpg (deflated 18%)
#   adding: dump/pred_wrong_adv_correct/label_tv_stand_pred_table_2_5nat_z.jpg (deflated 18%)
#   adding: dump/pred_wrong_adv_correct/label_tv_stand_pred_bookshelf_6_6adv_z.jpg (deflated 16%)
#   adding: dump/pred_wrong_adv_correct/label_vase_pred_flower_pot_0_2adv_x.jpg (deflated 19%)
#   adding: dump/pred_wrong_adv_correct/label_radio_pred_vase_2_2adv_x.jpg (deflated 20%)
#   adding: dump/pred_wrong_adv_correct/label_piano_pred_bed_2_4adv_y.jpg (deflated 23%)
#   adding: dump/pred_wrong_adv_correct/label_table_pred_bench_5_3nat_y.jpg (deflated 20%)
#   adding: dump/pred_wrong_adv_correct/label_piano_pred_mantel_1_2adv_x.jpg (deflated 16%)
# ...
